# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Matplotlib Basics**

# %%
x = np.linspace(0,5,11)
x
y = x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.title('hello')
plt.xlabel('number')
plt.ylabel('square')
# Out:
# Text(0, 0.5, 'square')

# %% [markdown]
# **Subplots in Matplotlib**

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,3)
plt.plot(x**3,y)
plt.subplot(2,2,4)
plt.plot(x**2,x**2)

# %% [markdown]
# **Object Oriented way**

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.7])
axes1.plot(x,y)
axes2 = fig.add_axes([0.2,0.48,0.3,0.3])
axes2.plot(x,y)
